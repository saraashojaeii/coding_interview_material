# %% [markdown]
# # Sliding Window
# ## Concept
#
# Use when you need a contiguous subarray / substring with some property (max length, min length, sum constraint).
#
# ## Key Python bits
#
# - Maintain window `[l, r]` while iterating `r`
#
# - Adjust `l` in a while loop when condition breaks

# %% [markdown]
# ### Template
# ```l = 0
# for r in range(len(arr)):
#     # include arr[r] in window
#     # update window state here
#
#     while window_is_invalid:
#         # remove arr[l] from window state
#         l += 1
#
#     # window [l, r] is valid; maybe update answer
#
# ```

# %% [markdown]
# ## Examples
# **Problem 1**: Length of longest substring without repeating characters.

# %%
def length_of_longest_substring(s: str) -> int:
    last_pos = {}
    l = 0
    best = 0
    
    for r, ch in enumerate(s):
        if ch in last_pos:
            l = r
        last_pos[ch] = r
        window = s[l:r+1]
        if len(window) > best:
            best = len(window)
            best_window = window
    return best, best_window
        


print(length_of_longest_substring("abcabcbb"))  # 3 ("abc")
print(length_of_longest_substring("bbbbb"))     # 1
# Out:
# (3, 'abc')
# (1, 'b')

# %% [markdown]
# **Problem 2** : Max Sum Subarray of Size K
#
# Input: nums: `List[int]`, k: `int`
#
# Output: maximum sum of any contiguous subarray of size `k`.

# %%
def max_sum_subarray(nums: list[int], k: int):
    max_sum = sum(nums[:k])
    temp_sum = max_sum
    for i in range (k, len(nums)):
        addition = nums[i] - nums[i-k]
        temp_sum += addition
        max_sum = max(max_sum, temp_sum)
    return max_sum

list1 = [1, 3, 4, 5, 7, 9]
list2 = [2, 1, 5, 1, 3, 2]
list3 = [10, 1, 1, 1]

print(max_sum_subarray(list1, 3))
print(max_sum_subarray(list2, 3))
print(max_sum_subarray(list3, 2))
# Out:
# 21
# 9
# 11

# %% [markdown]
# **Problem 3:** Smallest Subarray ≥ Target
#
# Input: `nums: List[int]`, `target: int` (all positive)
#
# Output: minimal length of subarray whose sum ≥ `target; if none, return 0.

# %%
def max_sum_subarray(nums: list[int], k: int):
    array_length = 1
    while array_length <= len(nums):
        temp_sum = sum(nums[0:array_length])
        for i in range (array_length, len(nums)):
            # print(temp_sum)
            if temp_sum >= k:
                return array_length
            
            temp_sum += nums[i] - nums[i-array_length]
        if temp_sum < k:
            array_length += 1
    return 0
    

list1 = [1, 3, 4, 5, 7, 9]
list2 = [1, 1, 1, 1, 3, 5]
list3 = [10, 1, 1, 1]

print(max_sum_subarray(list1, 10))
print(max_sum_subarray(list2, 8))
print(max_sum_subarray(list3, 2))
# Out:
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 21
#      18 list3 = [10, 1, 1, 1]
#      20 print(max_sum_subarray(list1, 10))
# ---> 21 print(max_sum_subarray(list2, 8))
#      22 print(max_sum_subarray(list3, 2))
#
# Cell In[56], line 10, in max_sum_subarray(nums, k)
#       7     if temp_sum >= k:
#       8         return array_length
# ---> 10     temp_sum += nums[i] - nums[i-array_length]
#      11 if temp_sum < k:
#      12     array_length += 1
#
# KeyboardInterrupt:
